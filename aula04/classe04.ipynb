# %% [markdown]
# AULA 04 - Estruturas de Repetição

# %%
for elemento in [1, 2, 3, 4, 5, 6]:
    print('Estamos no elemento', elemento)
# Out:
# Estamos no elemento 1
# Estamos no elemento 2
# Estamos no elemento 3
# Estamos no elemento 4
# Estamos no elemento 5
# Estamos no elemento 6

# %%
for elemento in 'STRING':
    print('Estamos no elemento', elemento)
# Out:
# Estamos no elemento S
# Estamos no elemento T
# Estamos no elemento R
# Estamos no elemento I
# Estamos no elemento N
# Estamos no elemento G

# %%
for elemento in range(len('STRING')):
    print('Estamos no elemento', elemento)
# Out:
# Estamos no elemento 0
# Estamos no elemento 1
# Estamos no elemento 2
# Estamos no elemento 3
# Estamos no elemento 4
# Estamos no elemento 5

# %%
elemento = 0

# %%
while elemento <= len ([1,2,3,4,5,6]):
    print('Estamos no elemento', elemento)
# Out:
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# Estamos no elemento 0
# ...

# %%
while elemento <= len([1, 2, 3, 4, 5, 6]):
    print('Estamos no elemento', elemento)
    elemento += 1

# %%
s = 'STRING'
indice = 0

while indice in range(len(s)):
    print('Estamos no elemento', s[indice])
    indice += 1
# Out:
# Estamos no elemento S
# Estamos no elemento T
# Estamos no elemento R
# Estamos no elemento I
# Estamos no elemento N
# Estamos no elemento G

# %%
palavra = 'tranquilo'
for indice, letra in enumerate(palavra):
    print(indice,letra)
# Out:
# 0 t
# 1 r
# 2 a
# 3 n
# 4 q
# 5 u
# 6 i
# 7 l
# 8 o

# %%
lista = ['eat', 'sleep', 'repeat']
palavra = 'geek'

# %%
objeto1 = enumerate(lista)
objeto2 = enumerate(palavra)

# %%
print('Tipo:', type(objeto1))
print(list(enumerate(lista)))
# Out:
# Tipo: <class 'enumerate'>
# [(0, 'eat'), (1, 'sleep'), (2, 'repeat')]

# %%
print(list(enumerate(palavra,2)))
# Out:
# [(2, 'g'), (3, 'e'), (4, 'e'), (5, 'k')]

# %% [markdown]
# QUIZ

# %%
s = 'viva o python'
for ch in s:
    print('oi')
# Out:
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi

# %%
s = 'viva o python'
for ch in s[3:8]:
    print('Oi')
# Out:
# Oi
# Oi
# Oi
# Oi
# Oi

# %% [markdown]
# DESAFIO 1

# %%
par = 0
impar = 0
for i in range (10):    
    num = int(input('Digite um número: '))
    if num % 2:
        par += 1
    else:
        impar += 1

print(f'pares: {par}')
print(f'impares: {impar}')
# Out:
# pares: 5
# impares: 5

# %% [markdown]
# DESAFIO 2

# %%
while True:
    
    dia = input('Digite um dia da semana: ').lower()

    if dia == 'sábado' or dia == 'domingo' or dia == 'sabado':
        print('Hoje é dia de descanso!')
    elif dia == '':
        break
    else:
        print(f'Hoje é {dia}. Você precisa trabalhar!')
# Out:
# Hoje é dia de descanso!
# Hoje é dia de descanso!
# Hoje é sexta. Você precisa trabalhar!

# %%
pares = list()

for i in range (10):
    num = int(input(''))
    if num % 2 == 0:
        pares.append(num)
        print(pares[i], end=' ')
# Out:
# 2 4

# %% [markdown]
# DESAFIO 4

# %%
palavra = input('Digite uma palavra: ')
vogais = ['a', 'e', 'i', 'o', 'u']

for indice, letra in enumerate(palavra):
    if letra in vogais:
        print(f'a vogal "{letra}" está na posição {indice}')
# Out:
# a letra "P" está na posição 0
# a vogal "a" está na posição 1
# a vogal "u" está na posição 2
# a letra "l" está na posição 3
# a vogal "o" está na posição 4

# %%
for nome in ['Rogério', 'Gisele Pintcher', 'Scoob', 'Marlene', 'Zezinho', 'Cibele', 'Suelly']:
    
    convite = ('Oi, ' + nome + '! Por favor, venha para o sábado pet em minha casa!')

    print(convite)
# Out:
# Oi, Rogério! Por favor, venha para o sábado pet em minha casa!
# Oi, Gisele Pintcher! Por favor, venha para o sábado pet em minha casa!
# Oi, Scoob! Por favor, venha para o sábado pet em minha casa!
# Oi, Marlene! Por favor, venha para o sábado pet em minha casa!
# Oi, Zezinho! Por favor, venha para o sábado pet em minha casa!
# Oi, Cibele! Por favor, venha para o sábado pet em minha casa!
# Oi, Suelly! Por favor, venha para o sábado pet em minha casa!

# %%
frutas = list('morango')

for fruta in range(5):
    entrada = input("Digite uma fruta: ").lower()
    if entrada == "morango":
        print(f'{entrada} está na lista')
        break
    else:
        print(f'Não há morango na lista')

# %%
for i in range(100, 151, 2):
    if i%2 == 0:
        print(f'{i}', end=' ')
# Out:
# 100 102 104 106 108 110 112 114 116 118 120 122 124 126 128 130 132 134 136 138 140 142 144 146 148 150

# %%
temperatura = 40

while temperatura > 25:
    print (f'A temperatura atual é: {temperatura}°C')
    temperatura -= 1
# Out:
# A temperatura atual é: 40°C
# A temperatura atual é: 39°C
# A temperatura atual é: 38°C
# A temperatura atual é: 37°C
# A temperatura atual é: 36°C
# A temperatura atual é: 35°C
# A temperatura atual é: 34°C
# A temperatura atual é: 33°C
# A temperatura atual é: 32°C
# A temperatura atual é: 31°C
# A temperatura atual é: 30°C
# A temperatura atual é: 29°C
# A temperatura atual é: 28°C
# A temperatura atual é: 27°C
# A temperatura atual é: 26°C
